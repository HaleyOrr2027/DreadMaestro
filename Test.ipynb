# %% [markdown]
# <a href="https://colab.research.google.com/github/HaleyOrr2027/DreadMaestro/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [1,2,3]
my_list
# Out:
# [1, 2, 3]

# %%
import torch
import numpy as np
np1 = np.random.rand(3,4) # three by four
np1
# Out:
# array([[0.10622346, 0.52930019, 0.6571311 , 0.90793731],
#        [0.68491415, 0.25514242, 0.51389114, 0.17621417],
#        [0.93304298, 0.00615383, 0.95128156, 0.00783592]])

# %%
tensor_2D = torch.randn(3,4)
tensor_2D
# Out:
# tensor([[ 0.6306, -0.0745, -1.0852, -0.9481],
#         [-1.1084,  0.1135, -0.3946, -0.6942],
#         [ 3.1390,  1.7142, -0.2918,  0.2739]])
